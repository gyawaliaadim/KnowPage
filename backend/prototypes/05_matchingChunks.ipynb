# %%
df=pd.read_json("chunks_with_vectors.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_json("chunks_with_vectors.json")
#
# NameError: name 'pd' is not defined

# %%
# =========================
# 4. EMBEDDING FUNCTION
# =========================
def create_embeddings_batch(texts):
    """
    Efficient batch embedding using SentenceTransformers.
    """
    return model.encode(
        texts,
        batch_size=32,
        show_progress_bar=True,
        normalize_embeddings=True  # important for cosine similarity search
    )

# %%
incoming_query=input("Ask a question: ")
question_embedding=embedding = create_embeddings_batch([incoming_query])[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 incoming_query=input("Ask a question: ")
# ----> 2 question_embedding=embedding = create_embeddings_batch([incoming_query])[0]
#
# NameError: name 'create_embeddings_batch' is not defined
